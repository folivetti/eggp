# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import eggp

# %% [markdown]
# In this exercise, we attempt to discover a polynomial model that generated three examples. We purposefully generate the examples choosing a free parameter equal to zero. In this configuration, no single example is enough to discover the full functional form that generated each view. However, as demonstrated in Russeil et al. 2024 (https://arxiv.org/abs/2402.04298), a multiview approach - i.e. considering multiple datasets generated by the same function - enables to find the correct solution.

# %%
np.random.seed(42)

# Define the true model to discover
def true_func(X, A, B, C):
    return A + B * X + C * X**2


# Define specific parameter values for each example.
true_params = [[0,-5, 2],
               [20, 0, -2],
               [2, 3, 0]]


# Generate the data and plot it 
full_X, full_y = [], []
plt.figure(figsize=(10, 7))
for idx, ps in enumerate(true_params):
    X = np.random.uniform(-5, 5, 15)
    y = true_func(X, *ps)
    yerr = np.random.normal(0, 2, size=len(y))
    plt.scatter(X, y+yerr, label=f'View {idx+1}', s=50)
    full_X += [np.array([X]).T]
    full_y += [y+yerr]

plt.legend(fontsize=16)
plt.show()

# %%
# We create a Pyeggp regressor leaving all hyperparameters to default.
reg = eggp.EGGP()
reg.fit_mvsr(full_X, full_y)

# Here we collect the full table of results and plot it
pareto = reg.results
pareto
# Out:
#     id  view                                         Expression  \
# 0    0     0                                 21.589217270548623
# 1    0     1                                 -2.930612339764867
# 2    0     2                                  2.667185093303495
# 3    1     0                          (21.534862886995523 - x0)
# 4    1     1                         (-3.2856867579965456 - x0)
# 5    1     2                          (2.6105987644181523 - x0)
# 6    2     0   (21.303011895450787 + (x0 * -5.265543575122987))
# 7    2     1  (-2.967195956970522 + (x0 * -0.103030844598327...
# 8    2     2    (2.8472358446081776 + (x0 * 3.181877228219174))
# 9    3     0  (x0 * (-4.997185434556597 + (x0 * 1.9710017166...
# 10   3     1  (x0 * (-0.3135539734579376 + (x0 * -0.84662961...
# 11   3     2  (x0 * (3.3024607194164286 + (x0 * 0.1925649130...
# 12   4     0  ((x0 + -2.645075648188035) * (0.40042646234334...
# 13   4     1  ((x0 + -3.071181811381864) * (-6.3508399143391...
# 14   4     2  ((x0 + 0.8166540308437522) * (3.17810840942135...
# 15   5     0  (-0.4710360148347207 + (-0.5880961667000076 + ...
# 16   5     1  (9.659149966450054 + (9.846772636698656 + (x0 ...
# 17   5     2  (2.111284332408068 + (0.4814748808300009 + (x0...
# 18   6     0  (-0.8961205388017053 + (x0 * (-5.4395816845627...
# 19   6     1  (19.505630796428246 + (x0 * (-0.10236401658211...
# 20   6     2  (2.1996473290308143 + (x0 * (3.542983731088475...
# 21   7     0  (((x0 + x0) + 0.31630659889596935) * (-2.87612...
# 22   7     1  (((x0 + x0) + 6.170996276888179) * (3.07682482...
# 23   7     2  (((x0 + x0) + 1.2472384958972085) * (1.8304820...
#
#                                                 Numpy  \
# 0                                                t[0]
# 1                                                t[0]
# 2                                                t[0]
# 3                                    (t[0] - x[:, 0])
# 4                                    (t[0] - x[:, 0])
# 5                                    (t[0] - x[:, 0])
# 6                           (t[0] + (x[:, 0] * t[1]))
# 7                           (t[0] + (x[:, 0] * t[1]))
# 8                           (t[0] + (x[:, 0] * t[1]))
# 9               (x[:, 0] * (t[0] + (x[:, 0] * t[1])))
# 10              (x[:, 0] * (t[0] + (x[:, 0] * t[1])))
# 11              (x[:, 0] * (t[0] + (x[:, 0] * t[1])))
# 12     ((x[:, 0] + t[0]) * (t[1] - (x[:, 0] * t[2])))
# 13     ((x[:, 0] + t[0]) * (t[1] - (x[:, 0] * t[2])))
# 14     ((x[:, 0] + t[0]) * (t[1] - (x[:, 0] * t[2])))
# 15  (t[0] + (t[1] + (x[:, 0] * (t[2] - (x[:, 0] * ...
# 16  (t[0] + (t[1] + (x[:, 0] * (t[2] - (x[:, 0] * ...
# 17  (t[0] + (t[1] + (x[:, 0] * (t[2] - (x[:, 0] * ...
# 18  (t[0] + (x[:, 0] * (t[1] - (x[:, 0] * (t[2] - ...
# 19  (t[0] + (x[:, 0] * (t[1] - (x[:, 0] * (t[2] - ...
# 20  (t[0] + (x[:, 0] * (t[1] - (x[:, 0] * (t[2] - ...
# 21  (((x[:, 0] + x[:, 0]) + t[0]) * (t[1] - (x[:, ...
# 22  (((x[:, 0] + x[:, 0]) + t[0]) * (t[1] - (x[:, ...
# 23  (((x[:, 0] + x[:, 0]) + t[0]) * (t[1] - (x[:, ...
#
#                                                  Math  \
# 0                                      $$\theta_{0}$$
# 1                                      $$\theta_{0}$$
# 2                                      $$\theta_{0}$$
# 3                 $$\left(\theta_{0} - x_{0}\right)$$
# 4                 $$\left(\theta_{0} - x_{0}\right)$$
# 5                 $$\left(\theta_{0} - x_{0}\right)$$
# 6   $$\left(\theta_{0} + \left(x_{0} \cdot \theta_...
# 7   $$\left(\theta_{0} + \left(x_{0} \cdot \theta_...
# 8   $$\left(\theta_{0} + \left(x_{0} \cdot \theta_...
# 9   $$\left(x_{0} \cdot \left(\theta_{0} + \left(x...
# 10  $$\left(x_{0} \cdot \left(\theta_{0} + \left(x...
# 11  $$\left(x_{0} \cdot \left(\theta_{0} + \left(x...
# 12  $$\left(\left(x_{0} + \theta_{0}\right) \cdot ...
# 13  $$\left(\left(x_{0} + \theta_{0}\right) \cdot ...
# 14  $$\left(\left(x_{0} + \theta_{0}\right) \cdot ...
# 15  $$\left(\theta_{0} + \left(\theta_{1} + \left(...
# 16  $$\left(\theta_{0} + \left(\theta_{1} + \left(...
# 17  $$\left(\theta_{0} + \left(\theta_{1} + \left(...
# 18  $$\left(\theta_{0} + \left(x_{0} \cdot \left(\...
# 19  $$\left(\theta_{0} + \left(x_{0} \cdot \left(\...
# 20  $$\left(\theta_{0} + \left(x_{0} \cdot \left(\...
# 21  $$\left(\left(\left(x_{0} + x_{0}\right) + \th...
# 22  $$\left(\left(\left(x_{0} + x_{0}\right) + \th...
# 23  $$\left(\left(\left(x_{0} + x_{0}\right) + \th...
#
#                                                 theta  size  loss_train  \
# 0                                  21.589217270548623     1  532.979453
# 1                                  -2.930612339764867     1  247.002956
# 2                                   2.667185093303495     1  126.303250
# 22    3.049501    3.049501    5.912268  9.876540e-01  9.876540e-01
# 23    4.678348    4.678348    5.912268  9.629594e-01  9.629594e-01
#
#          R2_test   mdl_train     mdl_val    mdl_test
# 0   2.220446e-16  532.979453  532.979453  532.979453
# 1   1.110223e-16  247.002956  247.002956  247.002956
# 2   0.000000e+00  126.303250  126.303250  126.303250
# 3   1.963168e-01  431.642488  431.642488  431.642488
# 4  -3.517772e-02  258.987794  258.987794  258.987794
# 5  -6.982464e-01  217.789882  217.789882  217.789882
# 6   5.710858e-01  235.533923  235.533923  235.533923
# 7   4.703438e-04  253.818252  253.818252  253.818252
# 8   9.600111e-01   11.982196   11.982196   11.982196
# 9   9.876776e-01   16.271623   16.271623   16.271623
# 10  4.884440e-01  136.059911  136.059911  136.059911
# 11  9.489074e-01   16.157226   16.157226   16.157226
# 12  9.883254e-01   20.707237   20.707237   20.707237
# 13  9.883385e-01   17.365369   17.365369   17.365369
# 14  9.601467e-01   19.518540   19.518540   19.518540
# 15  9.883254e-01   23.926112   23.926112   23.926112
# 16  9.883385e-01   20.584245   20.584245   20.584245
# 17  9.601467e-01   22.737416   22.737416   22.737416
# 18  9.889069e-01   26.835067   26.835067   26.835067
# 19  9.883393e-01   23.802925   23.802925   23.802925
# 20  9.625584e-01   25.651682   25.651682   25.651682
# 21  9.889071e-01   30.053836   30.053836   30.053836
# 22  9.876540e-01   27.191070   27.191070   27.191070
# 23  9.629594e-01   28.819917   28.819917   28.819917

# %% [markdown]
# All these solution can be quite confusing at first glance. Let's have a look at the evolution of the loss along the pareto front

# %%
fig, ax = plt.subplots(1, 3, figsize=(14, 4))

ax[0].plot(pareto['id'], -pareto['maxloss'], label='Pareto front')
ax[0].scatter(pareto['id'], -pareto['maxloss'])
ax[0].set_ylabel('Loss')
ax[0].legend()

n_params = pareto['theta'].apply(lambda x: x.split(';')).apply(len)
ax[1].plot(pareto['id'], n_params)
ax[1].scatter(pareto['id'], n_params)
ax[1].set_xlabel('ID')
ax[1].set_ylabel('Number of parameters')

ax[2].plot(pareto['id'], pareto['size'])
ax[2].scatter(pareto['id'], pareto['size'])
ax[2].set_ylabel('Equation size')

plt.show()

# %% [markdown]
# From the study of the pareto front, we see that solution 4 seems to be an excellent solution. Solution 5 and 6 do not lead to significant improvement, despite the increase in complexity in equation size and number of parameters. Therefore we apply Ockam's razor and select the simplest solution.
#
#
# Let's look at solution 4 in more details:

# %%
best_id = 4
model, clean_expression = reg.get_model(best_id)
print("Best solution :\n f(X0) = ", clean_expression)


X_smooth = np.array([np.linspace(-5, 5, 100)]).T
solution = pareto[pareto['id']==best_id]

plt.figure(figsize=(10, 7))
for idx in range(len(full_X)):

    params = np.array(solution.iloc[idx]['theta'].split(";"), dtype=float)
    plt.scatter(full_X[idx], full_y[idx], label=f'View {idx+1}', s=50)
    plt.plot(X_smooth, model(X_smooth, params))

plt.legend(fontsize=16)
plt.show()
# Out:
# Best solution :
#  f(X0) =  ((X0 + A) * (B - (X0 * C)))

# %% [markdown]
# Huray !! We rediscovered the generating model
